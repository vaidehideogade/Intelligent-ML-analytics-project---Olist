# %% [markdown]
# INTELLIGENT BUSINESS ANALYTICS AND FORECASTING SYSTEM

# %% [markdown]
# Project objectives:
#
# Build a complete end-to-end Machine learning system that transforms raw Olist e-commerce data into actionable business insight through 5 core ML techniques.

# %%
print("Running ML business application pipeline!")
# Out:
# Running ML business application pipeline!
